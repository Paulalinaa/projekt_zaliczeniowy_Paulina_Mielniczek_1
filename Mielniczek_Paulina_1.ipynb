# %%
import pandas as pd
df_zadanie = pd.read_csv("/dane1.csv")
df_zadanie
# Out:
#      coordinates                      created_at  \
# 0            NaN  Tue Jun 01 05:26:49 +0000 2021
# 1            NaN  Tue Jun 01 04:15:56 +0000 2021
# 2            NaN  Tue Jun 01 04:47:19 +0000 2021
# 3            NaN  Tue Jun 01 05:47:47 +0000 2021
# 4            NaN  Tue Jun 01 05:03:08 +0000 2021
# ...          ...                             ...
# 5098         NaN  Fri Jun 04 15:44:32 +0000 2021
# 5099         NaN  Fri Jun 04 15:39:10 +0000 2021
# 5100         NaN  Fri Jun 04 15:41:51 +0000 2021
# 5101         NaN  Fri Jun 04 15:42:02 +0000 2021
# 5102         NaN  Fri Jun 04 15:43:33 +0000 2021
#
#                            hashtags  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4     WspieramyRodziny DzieńDziecka
# ...                             ...
# 5098                            NaN
# 5099                            NaN
# 5100                            NaN
# ...

# %%
#Zadanie 1a
mapa_dni = {
    'Mon': 'Poniedziałek',
    'Tue': 'Wtorek',
    'Wed': 'Środa',
    'Thu': 'Czwartek',
    'Fri': 'Piątek',
    'Sat': 'Sobota',
    'Sun': 'Niedziela'
}
df_zadanie['created_at_polskie'] = df_zadanie['created_at'].str.replace(r'\b(?:Mon|Tue|Wed|Thu|Fri|Sat|Sun)\b', lambda x: mapa_dni[x.group()], regex=True)
print(df_zadanie["created_at_polskie"])
# Out:
# 0       Wtorek Jun 01 05:26:49 +0000 2021
# 1       Wtorek Jun 01 04:15:56 +0000 2021
# 2       Wtorek Jun 01 04:47:19 +0000 2021
# 3       Wtorek Jun 01 05:47:47 +0000 2021
# 4       Wtorek Jun 01 05:03:08 +0000 2021
#                       ...
# 5098    Piątek Jun 04 15:44:32 +0000 2021
# 5099    Piątek Jun 04 15:39:10 +0000 2021
# 5100    Piątek Jun 04 15:41:51 +0000 2021
# 5101    Piątek Jun 04 15:42:02 +0000 2021
# 5102    Piątek Jun 04 15:43:33 +0000 2021
# Name: created_at_polskie, Length: 5103, dtype: object

# %%
#zadanie 1b
mapa_miesiecy = {
    'Jan': '01',
    'Feb': '02',
    'Mar': '03',
    'Apr': '04',
    'May': '05',
    'Jun': '06',
    'Jul': '07',
    'Aug': '08',
    'Sep': '09',
    'Oct': '10',
    'Nov': '11',
    'Dec': '12'
}
df_zadanie['created_at_polskie'] = df_zadanie['created_at_polskie'].str.replace(r'\b(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)\b', lambda x: mapa_miesiecy[x.group()], regex=True)

print(df_zadanie["created_at_polskie"])
# Out:
# 0       Wtorek 06 01 05:26:49 +0000 2021
# 1       Wtorek 06 01 04:15:56 +0000 2021
# 2       Wtorek 06 01 04:47:19 +0000 2021
# 3       Wtorek 06 01 05:47:47 +0000 2021
# 4       Wtorek 06 01 05:03:08 +0000 2021
#                       ...
# 5098    Piątek 06 04 15:44:32 +0000 2021
# 5099    Piątek 06 04 15:39:10 +0000 2021
# 5100    Piątek 06 04 15:41:51 +0000 2021
# 5101    Piątek 06 04 15:42:02 +0000 2021
# 5102    Piątek 06 04 15:43:33 +0000 2021
# Name: created_at_polskie, Length: 5103, dtype: object

# %%
#zadanie 1c
tweet_urls_list = df_zadanie['tweet_url'].to_list()
print(tweet_urls_list[:3])# tylko 3 pierwsze
#bo jest ich aż...
print(len(tweet_urls_list))
# Out:
# ['https://twitter.com/MarkonMarek/status/1399598285082476544', 'https://twitter.com/21lupus/status/1399580447902994435', 'https://twitter.com/WTP_Warszawa/status/1399588347358633987']
# 5103

# %%
#zadanie 1d
media = df_zadanie['media'].dropna().tolist()
print(media[:3])# tylko 3 pierwsze
#bo jest ich aż...
print(len(media))
# Out:
# ['https://twitter.com/MarkonMarek/status/1399598285082476544/photo/1', 'https://twitter.com/j_wisniewska/status/1399592325324619780/photo/1', 'https://twitter.com/serhenryk/status/1399594808545480705/photo/1']
# 801

# %%
#zadanie 1e
# !pip install stop-words
from stop_words import get_stop_words
stop_words = get_stop_words('polish')

df_zadanie['text_without_stopwords'] = df_zadanie['text'].apply(lambda x: ' '.join([word for word in x.split() if word.lower() not in stop_words]))
print(df_zadanie['text'][0])
print("-------------------")
print(df_zadanie['text_without_stopwords'][0])
# Out:
# ...
# @beata_skwarska Warszawa 😀 https://t.co/W7BcySyuNd
# -------------------
# @beata_skwarska Warszawa 😀 https://t.co/W7BcySyuNd

# %%
#zadanie 2a
top5_tweetow = df_zadanie.sort_values(by='favorite_count', ascending=False).head(5)
print(top5_tweetow.loc[:, ['favorite_count', 'text']])
# Out:
#       favorite_count                                               text
# 4599            1386  Dziś z prezydent-elekt @Tsihanouskaya mówiliśm...
# 4012             744  Warszawa czeka na @Tsihanouskaya. #StandWithBe...
# 290              623  Jasio, który nie panuje nad swoją jadaczką, zn...
# 1466             605  Czyli prezydenci opozycji: \n👉Poznań -cieszy s...
# 1841             553  Pierwszy z 21 nowych pociągów @SKM_Warszawa ju...

# %%
#zadanie 2b
top5_retweetow  = df_zadanie.sort_values(by='retweet_count', ascending=False).head(5)
print(top5_retweetow.loc[:, ['retweet_count', 'text']])
# Out:
#       retweet_count                                               text
# 622            1638  HALO WARSZAWA\nchętnie rozjaśnię, ufarbuję, ze...
# 4383            896  ‼️\nA teraz perełka. Finał Was rozwali. \n10-1...
# 3904            865  UWAGA #Warszawa Śniadeckich 12/16\n\nPani Danu...
# 1190            865  UWAGA #Warszawa Śniadeckich 12/16\n\nPani Danu...
# 217             865  UWAGA #Warszawa Śniadeckich 12/16\n\nPani Danu...

# %%
#zadanie 2c
tweets_wrazliwe = df_zadanie[df_zadanie['possibly_sensitive'] != True]
print(tweets_wrazliwe.loc[:, ['possibly_sensitive', 'text']])
# Out:
#       possibly_sensitive                                               text
# 0                    NaN  @beata_skwarska Warszawa 😀 https://t.co/W7BcyS...
# 1                    NaN  Nieznani sprawcy podpalili kapliczkę nadrzewną...
# 2                    NaN  ⚠️ Utrudnienia w komunikacji: L20 https://t.co...
# 3                    NaN  @LukaszKohut @moanrosa @LincaAgata @jan_jozef_...
# 4                    NaN  Dzieci to największy skarb, o który musimy dba...
# ...                  ...                                                ...
# 5098                 NaN  Uroczystości odbyły się w 29. rocznicę upadku ...
# 5099                 NaN  @Jan11131258 @pikus_pol @dziennikarz @Prawo_do...
# 5100                 NaN  ❗KOCHANI, WAŻNE❗\njeśli macie taką możliwość, ...
# 5101                 NaN  Warszawa 04-06-2021\nBojówki OrdoZjebów w akcj...
# 5102                 NaN  https://t.co/3TSBVAk63h\nPuby i restauracje ju...
#
# [5078 rows x 2 columns]

# %%
#zadanie 2d
tweet_najwczesniej = df_zadanie['user_created_at'].min()
tweet_najwczesniej = df_zadanie[df_zadanie['user_created_at'] == tweet_najwczesniej]
print(tweet_najwczesniej.loc[:, ['user_created_at', 'text']])
# Out:
#                      user_created_at  \
# 1025  Fri Apr 01 19:39:20 +0000 2016
#
#                                                    text
# 1025  Paweł Wszołek odchodzi z Legii Warszawa. Dzięk...

# %%
#zadanie 2e
user_najpopularniejszy = df_zadanie.loc[df_zadanie['user_followers_count'].idxmax()]["user_id"]
tweety_user_najpopularniejszy = df_zadanie[df_zadanie['user_id'] == user_najpopularniejszy]
print(tweety_user_najpopularniejszy.loc[:, ['user_followers_count','user_screen_name', 'text']])
# Out:
#       user_followers_count user_screen_name  \
# 92                 1911494            tvn24
# 424                1911494            tvn24
# 1008               1911494            tvn24
# 2402               1911494            tvn24
# 2525               1911494            tvn24
# 3289               1911494            tvn24
# 3572               1911494            tvn24
#
#                                                    text
# 92    W poniedziałek późnym wieczorem na Mokotowie z...
# 424   Aktywista miejski Jan Śpiewak przegrał proces ...
# 1008  Sprawcy szuka policja.\n\nhttps://t.co/J5YwjOPMTy
# 2402  "Tylko w ostatnich czterech dniach zaszczepili...
# 2525  W środę po południu w okolicach mostu Świętokr...
# 3289  Zarząd Transportu Miejskiego zapowiada, że czę...
# 3572  "Jego spokój pozytywnie udziela się pozostałym...

# %%
#zadanie 2f
zweryfikowane = df_zadanie[df_zadanie['user_verified'] == True]
zweryfikowane = zweryfikowane['user_screen_name'].to_list()
print(zweryfikowane[:3])#  3 pierwsze
#bo jest ich...
print(len(zweryfikowane))
# Out:
# ['j_wisniewska', 'parents4future', 'gazeta_wyborcza']
# 191

# %%
#zadanie 2g
dzien_tygodnia = df_zadanie['created_at'].str[:3].map(mapa_dni).value_counts()
dzien_tygodnia_slownik = dzien_tygodnia.to_dict()
print(dzien_tygodnia_slownik)
# Out:
# {'Środa': 1657, 'Wtorek': 1476, 'Czwartek': 1202, 'Piątek': 768}

# %%
# Zadanie 3a
# !pip install spacy
# !python -m spacy download pl_core_news_sm
import spacy
nlp = spacy.load("pl_core_news_sm")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.2/20.2 MB 28.5 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('pl_core_news_sm')

# %%
#zadanie 3b
def detect_pers_names(text):
    doc = nlp(text)
    pers_names = []
    for ent in doc.ents:
        if ent.label_ == "persName":
            pers_names.append(ent.text)
    return pers_names

df_zadanie['persons'] = df_zadanie['text'].apply(detect_pers_names)
print(df_zadanie[df_zadanie['persons'].apply(len) > 0]['persons'])
# Out:
# 5                  [Wojciecha Korkucia]
# 6                  [Tadeusz Komorowski]
# 10                        [Trzaskowski]
# 27      [https://t.co/3TSBVAk63h\nPuby]
# 34                             [Banota]
#                      ...
# 5095      [Zygalski, Rejewski, Różycki]
# 5097                             [Jeju]
# 5099           [Warszawa - Śródmieście]
# 5100                             [Kasi]
# 5102    [https://t.co/3TSBVAk63h\nPuby]
# Name: persons, Length: 2338, dtype: object

# %%
#zadanie 3c
def detect_place_names(text):
    doc = nlp(text)
    place_names = []
    for ent in doc.ents:
        if ent.label_ == "placeName":
            place_names.append(ent.text)
    return place_names

df_zadanie['organizations'] = df_zadanie['text'].apply(detect_place_names)
print(df_zadanie[df_zadanie['organizations'].apply(len) > 0]['organizations'])
# Out:
# 0           [@beata_skwarska, Warszawa]
# 1              [warszawskim, Grochowie]
# 3       [Warszawa, polskiego, Warschau]
# 4                            [Warszawa]
# 5                            [Warszawa]
#                      ...
# 5095                           [Polscy]
# 5096                         [warszawa]
# 5097                 [Warszawa, Poland]
# 5100                         [Warszawa]
# 5101                         [Warszawa]
# Name: organizations, Length: 3119, dtype: object

# %%
#zadanie 3d
def detect_org_names(text):
    doc = nlp(text)
    org_names = []
    for ent in doc.ents:
        if ent.label_ == "orgName":
            org_names.append(ent.text)
    return org_names

df_zadanie['places'] = df_zadanie['text'].apply(detect_org_names)
print(df_zadanie[df_zadanie['places'].apply(len) > 0]['places'])
# Out:
# 2                                           [Utrudnienia]
# 4                               [https://t.co/S1IoJuhtiL]
# 5       [I Transportu, Społeczny Komitet 14, Galeria P...
# 6       [Polskich Sił Zbrojnych, Armii Krajowej, https...
# 7                                                    [😐.]
#                               ...
# 5096                                      [@EVASFINELINE]
# 5097                                                [금요일]
# 5099    [@Jan11131258 @pikus_pol @dziennikarz @Prawo_d...
# 5100                                            [KOCHANI]
# 5101                                                [ONR]
# Name: places, Length: 2449, dtype: object

# %%
import matplotlib.pyplot as plt
tydzien_dni = list(dzien_tygodnia.keys())
liczba_tweetow = list(dzien_tygodnia_slownik.values())

plt.bar(tydzien_dni, liczba_tweetow, color='pink')
plt.title('Liczba tweetów per dzień tygodnia')
plt.xlabel('Dzień tygodnia')
plt.ylabel('Liczba tweetów')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
